# %%
lst=[90,88,95,66,78]
print(lst)
print(len(lst))
print(lst[3])
print(lst[1])

print(lst[ :3])
print(lst.sort)
lst.reverse()
print(lst)
# Out:
# [90, 88, 95, 66, 78]
# 5
# 66
# 88
# [90, 88, 95]
# <built-in method sort of list object at 0x000001926301AA00>
# [78, 66, 95, 88, 90]

# %%
lst=[90,88,95,66,78]
lst.append(23)
print(lst)
lst.insert(2,99)
print(lst)
lst.pop(3)
print(lst)
# Out:
# [90, 88, 99, 95, 66, 78]
# [90, 88, 99, 66, 78]

# %%
lst=['s','d','k','u','c']
lst.reverse()
print(lst)
# Out:
# ['c', 'u', 'k', 'd', 's']
