# %%
info = {
    "name": "sachin",
    "sub": ["py", "math", "english"],
    "topic": ("dect", "set"),
    "age": 11,
    "is_adult": False,
    "marks": 99,
    9.2: 3
}

print(info)
# Out:
# {'name': 'sachin', 'sub': ['py', 'math', 'english'], 'topic': ('dect', 'set'), 'age': 11, 'is_adult': False, 'marks': 99, 9.2: 3}

# %%
student={
    "name":"sachin",
    "sub":{
        "phy":98,
        "chem":99,
        "math":100

    }
}
print(student.keys())
print(student.values())
print(list(student.items()))
print(student["name"])
print(student.get("name"))
student.update({"city":"delhi","name":"bais"})
print(student)
# Out:
# dict_keys(['name', 'sub'])
# dict_values(['sachin', {'phy': 98, 'chem': 99, 'math': 100}])
# [('name', 'sachin'), ('sub', {'phy': 98, 'chem': 99, 'math': 100})]
# sachin
# sachin
# {'name': 'bais', 'sub': {'phy': 98, 'chem': 99, 'math': 100}, 'city': 'delhi'}
