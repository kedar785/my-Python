# %%
n=0
while(n<5):
    print("hello")
    n+=1
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
i=1
n=int(input("Enter no"))
while i<=10:
    print(n*i)
    i+=1
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
nums=[2,5,21,54,65,45,1,99]
while idx<len(nums):
    print(nums[idx])
    idx+=1
# Out:
# 2
# 5
# 21
# 54
# 65
# 45
# 1
# 99

# %%
nums=[1,4,9,16,25,36,49,64,81,100]
x=36
i=0
while i<len(nums):
    if(nums[i]==x):
        print("found indx no.",i)
    i+=1
# Out:
# found indx no. 5

# %%
i=1
while i<=6:
    if(i==3):
      break
    print(i)
    i+=1
# Out:
# 1
# 2

# %%
str="helloe dosto"
for char in str:
    if(char=='o'):
        print("found o")
    print(char)
else:
    print("END")
# Out:
# h
# e
# l
# l
# found o
# o
# e
#
# d
# found o
# o
# s
# t
# found o
# o
# END

# %%
# factorial:-
n=5
fact=1
for i in range(1,n+1):
    fact*=i
print("factorial",fact)
# Out:
# factorial 120

# %% [markdown]
# # function:-

# %%
def cal_sum(a, b):
    sum= a + b
    print(sum)
    return sum


cal_sum(4,6)
cal_sum(2,7)
# Out:
# 10
# 9
# 9

# %%
def sum(a,b):
    return a+b
s=sum(2,9)
print(s)
# Out:
# 11
