# %%
str1="this is a string.\twe are creating a python"
len1=len(str1)
print(len1)
print(str1)
#concatination
str2="hello"
str3=" world"
print(str2+str3)
#indexing
str="mornig time"
print(str[3])
#Slicing
print(str[0:4])
print(str[ :6])
print(str[7:])
print(str[-5:-2])
# Out:
# 42
# this is a string.	we are creating a python
# hello world
# n
# morn
# mornig
# time
#  ti

# %%
str="i am studying python"
print(str.endswith("thon"))
print(str.capitalize())
print(str)
print(str.replace("y","u"))
print(str.find("x"))
print(str.count("n"))
# Out:
# True
# I am studying python
# i am studying python
# i am studuing puthon
# -1
# 2

# %%
str=input()
print(len(str))
str1="Hi, $Iam the $ symbol $99.99"
print(str1.count("$"))
# Out:
# 5
# 3

# %%
n=56
if(n%2==0):
    print("n is even")
else:
    print("n is odd")
# Out:
# n is even

# %%
a=4
b=6
c=9
if(a>b and a>c):
    print("a is greater")
elif(b>c):
    print("b is largest")
else:
    print("c is largest")
# Out:
# c is llargest

# %%
n=49
if(n%7==0):
    print("n is multiple a 7")
else:
    print("not a multiple is 7")
# Out:
# n is multiple a 7
