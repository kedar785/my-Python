# %%
def calc(a,b):
    sum=a+b
    print(sum)
    return sum


calc(3,6)
calc(5,2)
# Out:
# 9
# 7
# 7

# %%
def cal(a,b):
    return a+b

sum=cal(2,5)
print(sum)
# Out:
# 7

# %%
def avg(a,b,c):
    sum=a+b+c
    avrage=sum/3
    print(avrage)
    return  avrage

avg(88,99,77)
# Out:
# 88.0
# 88.0

# %%
print("apna",end=" ")
print("name")
# Out:
# apna name

# %%
range()

# %%
# defaut parameter
def prod(b , a=2):
    print(a*b)
    return a*b

 prod(1)
# Out:
#   File <string>:6
#     prod(1)
#            ^
# IndentationError: unindent does not match any outer indentation level

# %%
nums=["delhi","bhopal","jab","beo","rewa"]
city=["thor","hanuman","charka","rampur"]
print(nums[0],end=" ")
print(nums[1])

def print_len(list):
    print(len(list))
   
print_len(nums)
print_len(city)
# Out:
# delhi bhopal
# 5
# 4
