# %%
'''Write a Python program to create a dictionary named
student_grades with the following key-value pairs: 'Alice': 85, 'Bob':
90, 'Charlie': 78 and also print the dictionary.'''

s= {'Alice': 85, 'Bob':90, 'Charlie': 78}
print(s)
# Out:
# {'Alice': 85, 'Bob': 90, 'Charlie': 78}

# %%
s= {'Alice': 85, 'Bob':90, 'Charlie': 78}
print(s.get('Bob'))
# Out:
# 90

# %%
# Given dictionary
students = {'Alice': 85, 'Bob': 90, 'Charlie': 78}

# Add new student
students['David'] = 92

# Print updated dictionary
print(students)
# Out:
# {'Alice': 85, 'Bob': 90, 'Charlie': 78, 'David': 92}
