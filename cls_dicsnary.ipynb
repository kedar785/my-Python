# %%
# empty dictionary
dt={}
dt1=dict()
print(dt,dt1)
# Out:
# {} {}

# %%
dt={1:5,"hello":35,3.5:"pyrhon",7:2}
print(dt)
# Out:
# {1: 5, 'hello': 35, 3.5: 'pyrhon', 7: 2}

# %%
lst=[(2,5),(8,'hello'),(9,7.5),(8,5)]
d=dict(lst)
print(d)
# Out:
# {2: 5, 8: 5, 9: 7.5}

# %%
dt=[('name','kedar'),(3,6),('bais',100),(1.3,3.0)]

print(dt)
# Out:
# [('name', 'kedar'), (3, 6), ('bais', 100), (1.3, 3.0)]

# %%
dt={1:23,45:2,'hello':5.6,"hi":55,1:65}
print(dt.keys())
print(dt.values())
print(dt.items())
# Out:
# dict_keys([1, 45, 'hello', 'hi'])
# dict_values([65, 2, 5.6, 55])
# dict_items([(1, 65), (45, 2), ('hello', 5.6), ('hi', 55)])

# %% [markdown]
# WAP wich will orint sum of all the keys whose value are the factor of 12

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
print(dt.get(2))
# Out:
# 3

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}

del dt[3]
print(dt.pop(6))
print(dt)
# Out:
# 12
# {1: 2, 2: 3, 17: 18, 18: 12}

# %%
dt={1:2,2:3,3:4,6:12,17:18,18:12}
dt[6]="hello"
print(dt)
# Out:
# {1: 2, 2: 3, 3: 4, 6: 'hello', 17: 18, 18: 12}

# %%
subjects={}.fromkeys(('math','phy','chem'),0)
print(subjects)
# Out:
# {'math': 0, 'phy': 0, 'chem': 0}

# %%
squers={2:4,3:9,4:16,5:25}
s=squers # shallo copy
s[2]=6
print(s)
print(squers)
# Out:
# {2: 6, 3: 9, 4: 16, 5: 25}
# {2: 6, 3: 9, 4: 16, 5: 25}
